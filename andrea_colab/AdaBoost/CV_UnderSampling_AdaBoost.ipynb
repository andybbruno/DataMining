# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier
from imblearn.pipeline import Pipeline, make_pipeline
from imblearn.under_sampling import RandomUnderSampler


trainCSV = "https://raw.githubusercontent.com/andybbruno/DataMining/master/new_train_cleaned.csv?token=AGWKQXZRZZDVJOUEMOQ3PJC6AHO6U"

# %%
# READ AND DROP COLUMNS
df = pd.read_csv(trainCSV)
y = df['IsBadBuy']
X = df.drop(columns=['IsBadBuy'])

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# Set the parameters by cross-validation
params = {
    'n_estimators': [25, 50, 100, 200],
    'learning_rate' : [0.1, 0.25, 0.5, 0.75, 1],
 }

new_params = {'adaboostclassifier__' + key: params[key] for key in params}

#scores = ['precision', 'recall', 'f1']
scores = ['recall', 'f1']

for score in scores:
    print("# Tuning hyper-parameters for ----> %s" % score)
    print()
    
    obj = make_pipeline(RandomUnderSampler(), AdaBoostClassifier())
    
    if (score == "recall"):
      clf = GridSearchCV(obj, param_grid=new_params, cv=5, scoring=score)
    else:
      clf = GridSearchCV(obj, param_grid=new_params, cv=5, scoring='%s_macro' % score)
                         
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for ----> recall
#
# Best parameters set found on development set:
#
# {'adaboostclassifier__learning_rate': 1, 'adaboostclassifier__n_estimators': 200}
#
# Grid scores on development set:
#
# 0.467 (+/-0.047) for {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 25}
# 0.503 (+/-0.036) for {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 50}
# 0.543 (+/-0.039) for {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 100}
# 0.557 (+/-0.056) for {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 200}
# 0.526 (+/-0.040) for {'adaboostclassifier__learning_rate': 0.25, 'adaboostclassifier__n_estimators': 25}
# 0.558 (+/-0.058) for {'adaboostclassifier__learning_rate': 0.25, 'adaboostclassifier__n_estimators': 50}
# 0.567 (+/-0.039) for {'adaboostclassifier__learning_rate': 0.25, 'adaboostclassifier__n_estimators': 100}
# 0.585 (+/-0.057) for {'adaboostclassifier__learning_rate': 0.25, 'adaboostclassifier__n_estimators': 200}
# 0.567 (+/-0.044) for {'adaboostclassifier__learning_rate': 0.5, 'adaboostclassifier__n_estimators': 25}
# 0.588 (+/-0.055) for {'adaboostclassifier__learning_rate': 0.5, 'adaboostclassifier__n_estimators': 50}
# 0.574 (+/-0.048) for {'adaboostclassifier__learning_rate': 0.5, 'adaboostclassifier__n_estimators': 100}
# 0.594 (+/-0.029) for {'adaboostclassifier__learning_rate': 0.5, 'adaboostclassifier__n_estimators': 200}
# 0.590 (+/-0.054) for {'adaboostclassifier__learning_rate': 0.75, 'adaboostclassifier__n_estimators': 25}
# 0.591 (+/-0.056) for {'adaboostclassifier__learning_rate': 0.75, 'adaboostclassifier__n_estimators': 50}
# 0.595 (+/-0.055) for {'adaboostclassifier__learning_rate': 0.75, 'adaboostclassifier__n_estimators': 100}
# 0.591 (+/-0.037) for {'adaboostclassifier__learning_rate': 0.75, 'adaboostclassifier__n_estimators': 200}
# 0.592 (+/-0.044) for {'adaboostclassifier__learning_rate': 1, 'adaboostclassifier__n_estimators': 25}
# 0.596 (+/-0.039) for {'adaboostclassifier__learning_rate': 1, 'adaboostclassifier__n_estimators': 50}
# 0.592 (+/-0.044) for {'adaboostclassifier__learning_rate': 1, 'adaboostclassifier__n_estimators': 100}
# 0.605 (+/-0.036) for {'adaboostclassifier__learning_rate': 1, 'adaboostclassifier__n_estimators': 200}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.82     20507
#            1       0.24      0.58      0.34      2847
#
#     accuracy                           0.72     23354
#    macro avg       0.58      0.66      0.58     23354
# weighted avg       0.84      0.72      0.76     23354
#
#
# # Tuning hyper-parameters for ----> f1
#
# Best parameters set found on development set:
#
# {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 25}
#
# Grid scores on development set:
#
# 0.634 (+/-0.030) for {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 25}
# 0.625 (+/-0.007) for {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 50}
# 0.616 (+/-0.005) for {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 100}
# 0.613 (+/-0.012) for {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 200}
# 0.619 (+/-0.023) for {'adaboostclassifier__learning_rate': 0.25, 'adaboostclassifier__n_estimators': 25}
# 0.613 (+/-0.015) for {'adaboostclassifier__learning_rate': 0.25, 'adaboostclassifier__n_estimators': 50}
# 0.608 (+/-0.010) for {'adaboostclassifier__learning_rate': 0.25, 'adaboostclassifier__n_estimators': 100}
# 0.602 (+/-0.009) for {'adaboostclassifier__learning_rate': 0.25, 'adaboostclassifier__n_estimators': 200}
# 0.607 (+/-0.014) for {'adaboostclassifier__learning_rate': 0.5, 'adaboostclassifier__n_estimators': 25}
# 0.605 (+/-0.010) for {'adaboostclassifier__learning_rate': 0.5, 'adaboostclassifier__n_estimators': 50}
# 0.597 (+/-0.016) for {'adaboostclassifier__learning_rate': 0.5, 'adaboostclassifier__n_estimators': 100}
# 0.597 (+/-0.014) for {'adaboostclassifier__learning_rate': 0.5, 'adaboostclassifier__n_estimators': 200}
# 0.599 (+/-0.016) for {'adaboostclassifier__learning_rate': 0.75, 'adaboostclassifier__n_estimators': 25}
# 0.596 (+/-0.006) for {'adaboostclassifier__learning_rate': 0.75, 'adaboostclassifier__n_estimators': 50}
# 0.598 (+/-0.008) for {'adaboostclassifier__learning_rate': 0.75, 'adaboostclassifier__n_estimators': 100}
# 0.590 (+/-0.007) for {'adaboostclassifier__learning_rate': 0.75, 'adaboostclassifier__n_estimators': 200}
# 0.598 (+/-0.015) for {'adaboostclassifier__learning_rate': 1, 'adaboostclassifier__n_estimators': 25}
# 0.596 (+/-0.005) for {'adaboostclassifier__learning_rate': 1, 'adaboostclassifier__n_estimators': 50}
# 0.590 (+/-0.007) for {'adaboostclassifier__learning_rate': 1, 'adaboostclassifier__n_estimators': 100}
# 0.585 (+/-0.011) for {'adaboostclassifier__learning_rate': 1, 'adaboostclassifier__n_estimators': 200}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89     20507
#            1       0.31      0.44      0.36      2847
#
#     accuracy                           0.81     23354
#    macro avg       0.61      0.65      0.63     23354
# weighted avg       0.84      0.81      0.82     23354
