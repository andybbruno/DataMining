# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier


trainCSV = "https://raw.githubusercontent.com/andybbruno/DataMining/master/new_train_cleaned.csv?token=AGWKQX6PGJXV4U2SBDZHALC6BY3P4"

# %%
# READ AND DROP COLUMNS
df = pd.read_csv(trainCSV)
df.drop(df.columns[0], axis=1, inplace=True)
y = df['IsBadBuy']
X = df.drop(columns=['IsBadBuy'])

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = {
    'n_estimators': [5, 10, 25, 50, 100],
    'learning_rate' : [0.1, 0.25, 0.5, 0.75, 1],
 }

#scores = ['precision', 'recall', 'f1']
scores = ['recall', 'f1']

for score in scores:
    print("# Tuning hyper-parameters for ----> %s" % score)
    print()
    
    obj = AdaBoostClassifier()
    
    if (score == "recall"):
      clf = GridSearchCV(obj, tuned_parameters, cv=5, scoring=score)
    else:
      clf = GridSearchCV(obj, tuned_parameters, cv=5, scoring='%s_macro' % score)

    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for ----> recall
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.1, 'n_estimators': 5}
#
# Grid scores on development set:
#
# 0.258 (+/-0.033) for {'learning_rate': 0.1, 'n_estimators': 5}
# 0.258 (+/-0.033) for {'learning_rate': 0.1, 'n_estimators': 10}
# 0.250 (+/-0.040) for {'learning_rate': 0.1, 'n_estimators': 25}
# 0.244 (+/-0.032) for {'learning_rate': 0.1, 'n_estimators': 50}
# 0.243 (+/-0.032) for {'learning_rate': 0.1, 'n_estimators': 100}
# 0.258 (+/-0.033) for {'learning_rate': 0.25, 'n_estimators': 5}
# 0.244 (+/-0.031) for {'learning_rate': 0.25, 'n_estimators': 10}
# 0.242 (+/-0.031) for {'learning_rate': 0.25, 'n_estimators': 25}
# 0.244 (+/-0.031) for {'learning_rate': 0.25, 'n_estimators': 50}
# 0.244 (+/-0.030) for {'learning_rate': 0.25, 'n_estimators': 100}
# 0.223 (+/-0.076) for {'learning_rate': 0.5, 'n_estimators': 5}
# 0.244 (+/-0.032) for {'learning_rate': 0.5, 'n_estimators': 10}
# 0.242 (+/-0.028) for {'learning_rate': 0.5, 'n_estimators': 25}
# 0.243 (+/-0.031) for {'learning_rate': 0.5, 'n_estimators': 50}
# 0.241 (+/-0.031) for {'learning_rate': 0.5, 'n_estimators': 100}
# 0.244 (+/-0.031) for {'learning_rate': 0.75, 'n_estimators': 5}
# 0.243 (+/-0.031) for {'learning_rate': 0.75, 'n_estimators': 10}
# 0.243 (+/-0.031) for {'learning_rate': 0.75, 'n_estimators': 25}
# 0.243 (+/-0.032) for {'learning_rate': 0.75, 'n_estimators': 50}
# 0.238 (+/-0.033) for {'learning_rate': 0.75, 'n_estimators': 100}
# 0.244 (+/-0.032) for {'learning_rate': 1, 'n_estimators': 5}
# 0.243 (+/-0.029) for {'learning_rate': 1, 'n_estimators': 10}
# 0.244 (+/-0.034) for {'learning_rate': 1, 'n_estimators': 25}
# 0.242 (+/-0.031) for {'learning_rate': 1, 'n_estimators': 50}
# 0.240 (+/-0.035) for {'learning_rate': 1, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94     20507
#            1       0.71      0.25      0.37      2847
#
#     accuracy                           0.90     23354
#    macro avg       0.81      0.62      0.65     23354
# weighted avg       0.88      0.90      0.87     23354
#
#
# # Tuning hyper-parameters for ----> f1
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.1, 'n_estimators': 5}
#
# Grid scores on development set:
#
# 0.660 (+/-0.019) for {'learning_rate': 0.1, 'n_estimators': 5}
# 0.660 (+/-0.019) for {'learning_rate': 0.1, 'n_estimators': 10}
# 0.656 (+/-0.023) for {'learning_rate': 0.1, 'n_estimators': 25}
# 0.652 (+/-0.019) for {'learning_rate': 0.1, 'n_estimators': 50}
# 0.652 (+/-0.019) for {'learning_rate': 0.1, 'n_estimators': 100}
# 0.660 (+/-0.019) for {'learning_rate': 0.25, 'n_estimators': 5}
# 0.653 (+/-0.019) for {'learning_rate': 0.25, 'n_estimators': 10}
# 0.651 (+/-0.018) for {'learning_rate': 0.25, 'n_estimators': 25}
# 0.652 (+/-0.018) for {'learning_rate': 0.25, 'n_estimators': 50}
# 0.653 (+/-0.018) for {'learning_rate': 0.25, 'n_estimators': 100}
# 0.640 (+/-0.045) for {'learning_rate': 0.5, 'n_estimators': 5}
# 0.653 (+/-0.019) for {'learning_rate': 0.5, 'n_estimators': 10}
# 0.651 (+/-0.016) for {'learning_rate': 0.5, 'n_estimators': 25}
# 0.652 (+/-0.019) for {'learning_rate': 0.5, 'n_estimators': 50}
# 0.651 (+/-0.019) for {'learning_rate': 0.5, 'n_estimators': 100}
# 0.653 (+/-0.019) for {'learning_rate': 0.75, 'n_estimators': 5}
# 0.652 (+/-0.018) for {'learning_rate': 0.75, 'n_estimators': 10}
# 0.652 (+/-0.019) for {'learning_rate': 0.75, 'n_estimators': 25}
# 0.652 (+/-0.020) for {'learning_rate': 0.75, 'n_estimators': 50}
# 0.650 (+/-0.020) for {'learning_rate': 0.75, 'n_estimators': 100}
# 0.653 (+/-0.019) for {'learning_rate': 1, 'n_estimators': 5}
# 0.652 (+/-0.017) for {'learning_rate': 1, 'n_estimators': 10}
# 0.653 (+/-0.021) for {'learning_rate': 1, 'n_estimators': 25}
# 0.652 (+/-0.020) for {'learning_rate': 1, 'n_estimators': 50}
# 0.650 (+/-0.021) for {'learning_rate': 1, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94     20507
#            1       0.71      0.25      0.37      2847
#
#     accuracy                           0.90     23354
#    macro avg       0.81      0.62      0.65     23354
# weighted avg       0.88      0.90      0.87     23354
